#      -- ---------------------------------- 32.1/587.7 MB 847.0 kB/s eta 0:10:56
#      -- ---------------------------------- 32.2/587.7 MB 845.9 kB/s eta 0:10:57
#      -- ---------------------------------- 32.2/587.7 MB 842.6 kB/s eta 0:11:00
#      -- ---------------------------------- 32.2/587.7 MB 839.3 kB/s eta 0:11:02
#      -- ---------------------------------- 32.2/587.7 MB 838.3 kB/s eta 0:11:03
#      -- ---------------------------------- 32.3/587.7 MB 834.0 kB/s eta 0:11:06
#      -- ---------------------------------- 32.3/587.7 MB 831.9 kB/s eta 0:11:08
#      -- ---------------------------------- 32.3/587.7 MB 828.7 kB/s eta 0:11:11
#      -- ---------------------------------- 32.3/587.7 MB 828.7 kB/s eta 0:11:11
#      -- ---------------------------------- 32.4/587.7 MB 825.6 kB/s eta 0:11:13
#      -- ---------------------------------- 32.4/587.7 MB 823.5 kB/s eta 0:11:15
#      -- ---------------------------------- 32.4/587.7 MB 823.5 kB/s eta 0:11:15
#      -- ---------------------------------- 32.5/587.7 MB 818.4 kB/s eta 0:11:19
#      -- ---------------------------------- 32.5/587.7 MB 817.3 kB/s eta 0:11:20
#      -- ---------------------------------- 32.5/587.7 MB 812.3 kB/s eta 0:11:24
#      -- ---------------------------------- 32.5/587.7 MB 811.3 kB/s eta 0:11:25
#      -- ---------------------------------- 32.6/587.7 MB 809.3 kB/s eta 0:11:26
#      -- ---------------------------------- 32.6/587.7 MB 806.3 kB/s eta 0:11:29
#      -- ---------------------------------- 32.7/587.7 MB 804.3 kB/s eta 0:11:31
#      -- ---------------------------------- 32.7/587.7 MB 804.3 kB/s eta 0:11:31
#      -- ---------------------------------- 32.7/587.7 MB 798.5 kB/s eta 0:11:36
#      -- ---------------------------------- 32.7/587.7 MB 797.5 kB/s eta 0:11:36
#      -- ---------------------------------- 32.7/587.7 MB 794.5 kB/s eta 0:11:39
#      -- ---------------------------------- 32.8/587.7 MB 792.6 kB/s eta 0:11:41
#      -- ---------------------------------- 32.8/587.7 MB 790.7 kB/s eta 0:11:42
#      -- ---------------------------------- 32.8/587.7 MB 789.8 kB/s eta 0:11:43
#      -- ---------------------------------- 32.9/587.7 MB 786.9 kB/s eta 0:11:46
#      -- ---------------------------------- 32.9/587.7 MB 785.0 kB/s eta 0:11:47
#      -- ---------------------------------- 32.9/587.7 MB 782.2 kB/s eta 0:11:50
#      -- ---------------------------------- 33.0/587.7 MB 780.4 kB/s eta 0:11:51
#      -- ---------------------------------- 33.0/587.7 MB 776.6 kB/s eta 0:11:55
#      -- ---------------------------------- 33.1/587.7 MB 778.5 kB/s eta 0:11:53
#      -- ---------------------------------- 33.1/587.7 MB 774.8 kB/s eta 0:11:56
#      -- ---------------------------------- 33.2/587.7 MB 772.9 kB/s eta 0:11:58
#      -- ---------------------------------- 33.2/587.7 MB 769.3 kB/s eta 0:12:01
#      -- ---------------------------------- 33.2/587.7 MB 767.5 kB/s eta 0:12:03
#      -- ---------------------------------- 33.2/587.7 MB 763.9 kB/s eta 0:12:06
#      -- ---------------------------------- 33.3/587.7 MB 762.2 kB/s eta 0:12:08
#      -- ---------------------------------- 34.3/587.7 MB 709.3 kB/s eta 0:13:01
#      -- ---------------------------------- 34.4/587.7 MB 707.0 kB/s eta 0:13:03
#      -- ---------------------------------- 34.4/587.7 MB 707.0 kB/s eta 0:13:03
#      -- ---------------------------------- 34.4/587.7 MB 703.2 kB/s eta 0:13:07
#      -- ---------------------------------- 34.4/587.7 MB 703.2 kB/s eta 0:13:07
#      -- ---------------------------------- 34.5/587.7 MB 700.2 kB/s eta 0:13:11
#      -- ---------------------------------- 34.5/587.7 MB 698.8 kB/s eta 0:13:12
#      -- ---------------------------------- 34.5/587.7 MB 698.0 kB/s eta 0:13:13
#      -- ---------------------------------- 34.6/587.7 MB 697.2 kB/s eta 0:13:14
#      -- ---------------------------------- 34.6/587.7 MB 697.2 kB/s eta 0:13:14
#      -- ---------------------------------- 34.7/587.7 MB 694.2 kB/s eta 0:13:17
# ...
#      -------------------------------------  579.7/587.7 MB 2.5 MB/s eta 0:00:04
#      -------------------------------------  579.7/587.7 MB 2.5 MB/s eta 0:00:04
#      -------------------------------------  579.8/587.7 MB 2.5 MB/s eta 0:00:04
#      -------------------------------------  579.9/587.7 MB 2.5 MB/s eta 0:00:04
#      -------------------------------------  580.1/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.2/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.3/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.4/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.4/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.6/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.6/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.7/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.7/587.7 MB 2.5 MB/s eta 0:00:03
#      -------------------------------------  580.9/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  580.9/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.0/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.1/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.2/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.4/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.4/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.6/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.6/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.7/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.7/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  581.8/587.7 MB 2.3 MB/s eta 0:00:03
#      -------------------------------------  581.9/587.7 MB 2.4 MB/s eta 0:00:03
#      -------------------------------------  582.0/587.7 MB 2.3 MB/s eta 0:00:03
#      -------------------------------------  582.2/587.7 MB 2.3 MB/s eta 0:00:03
#      -------------------------------------  582.2/587.7 MB 2.3 MB/s eta 0:00:03
anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %% [markdown]
# ## Let’s Try on Real Dataset1

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Change 'html5lib' to 'html.parser'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.reuters.com/markets/how-companies-are-responding-attacks-ships-red-sea-2023-12-19/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 1

# %% [markdown]
# ## Have a Look At The NERS

# %%
# Visualize named entities in the article using displacy
from spacy import displacy
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">reuters.comPlease enable
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and disable any ad blocker </div></span>

# %% [markdown]
# ## Popular NER Types

# %%
# Count the frequency of each named entity label in the article
from collections import Counter
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'GPE': 1})

# %% [markdown]
# ## Most Popular NER

# %%
# Extract the text of each named entity in the article and count the most common 5 entities
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('JS', 1)]

# %% [markdown]
# ## Let’s Pick One Sentence to Analyze

# %%
# Extract sentences from the article and print the first sentence
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# reuters.comPlease enable JS and disable any ad blocker

# %% [markdown]
# ## NER Tags

# %%
# Visualize named entities in the first sentence of the article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">reuters.comPlease enable
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and disable any ad blocker</div></span>

# %% [markdown]
# ## Types of Words in Sentence

# %%
# Extract orthographic form, part-of-speech, and lemma of non-stopword, non-punctuation tokens in the first sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y
                                      for y
                                      in nlp(str(sentences[0]))
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('reuters.comPlease', 'INTJ', 'reuters.complease'),
#  ('enable', 'VERB', 'enable'),
#  ('JS', 'PROPN', 'JS'),
#  ('disable', 'VERB', 'disable'),
#  ('ad', 'NOUN', 'ad'),
#  ('blocker', 'NOUN', 'blocker')]

# %% [markdown]
# ## Sentence Dependency Tree

# %%
# Visualize dependency parse of the first sentence of the article with custom distance between words
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True,
                options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="742d6e2269af4f7182c654cc0a13347a-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">reuters.comPlease</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">enable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">JS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">disable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">ad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">blocker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,184.0 L288.0,172.0 272.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-2" stroke-width="2px" d="M190,182.0 C190,62.0 405.0,62.0 405.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M405.0,184.0 L413.0,172.0 397.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-3" stroke-width="2px" d="M190,182.0 C190,2.0 530.0,2.0 530.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,184.0 L538.0,172.0 522.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-4" stroke-width="2px" d="M670,182.0 C670,62.0 885.0,62.0 885.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-5" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,184.0 L782,172.0 798,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-742d6e2269af4f7182c654cc0a13347a-0-6" stroke-width="2px" d="M550,182.0 C550,2.0 890.0,2.0 890.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-742d6e2269af4f7182c654cc0a13347a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,184.0 L898.0,172.0 882.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Let’s Try on Real Dataset2

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Change 'html5lib' to 'html.parser'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://timesofindia.indiatimes.com/sports/cricket/match-center-scorecard/Gujarat%20Titans-vs-Mumbai%20Indians-live-score-update-indian-premier-league-2024/ahmmi03242024237775')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 87

# %% [markdown]
# ## Have a Look At The NERS

# %%
# Visualize named entities in the article using displacy
from spacy import displacy
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gujarat Titans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vs
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Live Ball by Ball Commentary, Scorecard, News,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , City and Squads and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moreEditionININUSRead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ePaperSign InTOIcricketIPL 2024WPLCricket ScheduleLive Cricket ScoreICC RankingsNEWSSPORTS
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEWSCRICKET
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEWSMatch CenterGujarat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  Titans vs
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Live ScoreGT168/620.0 ovsMatch
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     507:30p.m.24 Mar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024MI162/920.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ovsGujarat Titans beat
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  runsView Scorecard Top Cricket News IPL: Titans pull off a heist as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  begin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     another season
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with defeat'I have never seen any...':
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  being booed by crowdIPL
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stars in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rajasthan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's win over Lucknow'Why are we even discussing...': PCB on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's participation in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTBumrah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  makes stunning
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IPL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  comeback, registers new recordAshwin hails 'unsung hero'
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6

# %% [markdown]
# ## Popular NER Types

# %%
# Count the frequency of each named entity label in the article
from collections import Counter
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 38,
#          'GPE': 14,
#          'NORP': 6,
#          'PRODUCT': 2,
#          'DATE': 4,
#          'CARDINAL': 7,
#          'PERSON': 12,
#          'WORK_OF_ART': 2,
#          'EVENT': 1,
#          'MONEY': 1})

# %% [markdown]
# ## Most Popular NER

# %%
# Extract the text of each named entity in the article and count the most common 5 entities
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('Mumbai', 3), ('Indians', 3), ('2024', 3), ('Watan', 2), ('NewsTimes', 2)]

# %% [markdown]
# ## Let’s Pick One Sentence to Analyze

# %%
# Extract sentences from the article and print the first sentence
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# Gujarat Titans vs Mumbai Indians Live Ball by Ball Commentary, Scorecard, News, Venue, City and Squads and moreEditionININUSRead ePaperSign InTOIcricketIPL

# %% [markdown]
# ## NER Tags

# %%
# Visualize named entities in the first sentence of the article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gujarat Titans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vs
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Live Ball by Ball Commentary, Scorecard, News,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , City and Squads and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moreEditionININUSRead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ePaperSign InTOIcricketIPL</div></span>

# %% [markdown]
# ## Types of Words in Sentence

# %%
# Extract orthographic form, part-of-speech, and lemma of non-stopword, non-punctuation tokens in the first sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y
                                      for y
                                      in nlp(str(sentences[0]))
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Gujarat', 'PROPN', 'Gujarat'),
#  ('Titans', 'PROPN', 'Titans'),
#  ('vs', 'ADP', 'vs'),
#  ('Mumbai', 'PROPN', 'Mumbai'),
#  ('Indians', 'PROPN', 'Indians'),
#  ('Live', 'VERB', 'live'),
#  ('Ball', 'PROPN', 'Ball'),
#  ('Ball', 'PROPN', 'Ball'),
#  ('Commentary', 'PROPN', 'Commentary'),
#  ('Scorecard', 'PROPN', 'Scorecard'),
#  ('News', 'PROPN', 'News'),
#  ('Venue', 'PROPN', 'Venue'),
#  ('City', 'PROPN', 'City'),
#  ('Squads', 'PROPN', 'Squads'),
#  ('moreEditionININUSRead', 'PROPN', 'moreEditionININUSRead'),
#  ('ePaperSign', 'VERB', 'epapersign'),
#  ('InTOIcricketIPL', 'X', 'intoicricketipl')]

# %% [markdown]
# ## Sentence Dependency Tree

# %%
# Visualize dependency parse of the first sentence of the article with custom distance between words
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True,
                options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="312467b73e144f27a417700a33293a95-0" class="displacy" width="2450" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Gujarat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Titans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">vs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Mumbai</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Indians</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Ball</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Ball</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Commentary,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Scorecard,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">News,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Venue,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">City</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Squads</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">moreEditionININUSRead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">ePaperSign</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">InTOIcricketIPL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-312467b73e144f27a417700a33293a95-0-0" stroke-width="2px" d="M70,362.0 C70,302.0 145.0,302.0 145.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-312467b73e144f27a417700a33293a95-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,364.0 L62,352.0 78,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-312467b73e144f27a417700a33293a95-0-1" stroke-width="2px" d="M190,362.0 C190,182.0 635.0,182.0 635.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-312467b73e144f27a417700a33293a95-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,364.0 L182,352.0 198,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-312467b73e144f27a417700a33293a95-0-2" stroke-width="2px" d="M190,362.0 C190,302.0 265.0,302.0 265.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-312467b73e144f27a417700a33293a95-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M265.0,364.0 L273.0,352.0 257.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-312467b73e144f27a417700a33293a95-0-3" stroke-width="2px" d="M430,362.0 C430,302.0 505.0,302.0 505.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-312467b73e144f27a417700a33293a95-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,364.0 L422,352.0 438,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-312467b73e144f27a417700a33293a95-0-4" stroke-width="2px" d="M310,362.0 C310,242.0 510.0,242.0 510.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-312467b73e1

# %% [markdown]
# ## Importing SpaCy in German(Dutch)

# %%
# !python -m spacy download de_core_news_lg
import spacy
# Load the German language model
nlp = spacy.load("de_core_news_lg")

# %% [markdown]
# ## Let’s Try on Real Dataset3

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Change 'html5lib' to 'html.parser'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.sueddeutsche.de/sport/kroos-dfb-frankreich-nagelsmann-deutschland-1.6484717?reduced=true')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 138

# %% [markdown]
# ## Have a Look At The NERS

# %%
# Visualize named entities in the article using displacy
from spacy import displacy
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deutschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  und das
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2:0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gegen Frankreich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     der Große  -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sport - SZ.de Zum Hauptinhalt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  springenSZ.deZeitungMagazinJetztDossierAlle
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SZ-Produkte LoginMenüMenüSuchenSüddeutsche
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ZeitungJetzt abonnierenLoginMenüMenüSuchenSüddeutsche
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZeitungMeine SZSZ PlusUkraineIsraelPolitikWirtschaftMeinungPanoramaSportMünchenKulturMedienBayernReportageGesellschaftStilWissenKarriereGesundheitBildungReiseAutomehr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  HomeSportFußballDeutsche NationalmannschaftDeutschland und das
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2:0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gegen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankreich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     der Große DFB-Team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     der Große24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . März
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13:01
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UhrDetailansicht
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  öffnenGuter Start:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos bereitet das
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1:0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  von
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florian Wirtz vom Anstoßpunkt aus vor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Foto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexander Hassenstein/Getty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Images)Was für eine
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rückkehr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6

# %% [markdown]
# ## Popular NER Types

# %%
# Count the frequency of each named entity label in the article
from collections import Counter
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'GPE': 6,
#          'CARDINAL': 10,
#          'ORG': 39,
#          'PERSON': 60,
#          'DATE': 2,
#          'PRODUCT': 3,
#          'NORP': 1,
#          'MONEY': 1,
#          'FAC': 6,
#          'PERCENT': 9,
#          'LOC': 1})

# %% [markdown]
# ## Most Popular NER

# %%
# Extract the text of each named entity in the article and count the most common 5 entities
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('Gutschein', 3),
#  ('2:0', 2),
#  ('Toni Kroos', 2),
#  ('gegen', 2),
#  ('bei eBay', 2)]

# %% [markdown]
# ## Let’s Pick One Sentence to Analyze

# %%
# Extract sentences from the article and print the first sentence
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# Deutschland und das 2:0

# %% [markdown]
# ## NER Tags

# %%
# Visualize named entities in the first sentence of the article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deutschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  und das
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2:0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </div></span>

# %% [markdown]
# ## Types of Words in Sentence

# %%
# Extract orthographic form, part-of-speech, and lemma of non-stopword, non-punctuation tokens in the first sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y
                                      for y
                                      in nlp(str(sentences[0]))
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Deutschland', 'PROPN', 'Deutschland'),
#  ('und', 'VERB', 'und'),
#  ('das', 'VERB', 'da'),
#  ('2:0', 'NUM', '2:0')]

# %% [markdown]
# ## Sentence Dependency Tree

# %%
# Visualize dependency parse of the first sentence of the article with custom distance between words
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True,
                options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5eb051339a7d4b99b2e773355df1354f-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Deutschland</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">und</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">2:0</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5eb051339a7d4b99b2e773355df1354f-0-0" stroke-width="2px" d="M70,122.0 C70,2.0 290.0,2.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5eb051339a7d4b99b2e773355df1354f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5eb051339a7d4b99b2e773355df1354f-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5eb051339a7d4b99b2e773355df1354f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5eb051339a7d4b99b2e773355df1354f-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5eb051339a7d4b99b2e773355df1354f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M405.0,124.0 L413.0,112.0 397.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>
